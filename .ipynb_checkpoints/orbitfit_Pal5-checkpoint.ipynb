# %%
import numpy as np
import pickle
from astropy.io import fits
import matplotlib.pyplot as plt
from galpy.util import bovy_conversion, bovy_coords, save_pickles, bovy_plot
from galpy.potential import MWPotential2014, turn_physical_off, vcirc
import astropy.units as u
# %pylab inline
from galpy.orbit import Orbit
import random
import pal5_util
import pal5_util_MWfit
import MWPotential2014Likelihood
import os, os.path
import re
import glob
import pickle
import csv
_REFR0, _REFV0= MWPotential2014Likelihood._REFR0, MWPotential2014Likelihood._REFV0
ro, vo= _REFR0, _REFV0
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Jo tested 32 different MW potential models by varying $(f_{d},f_{r},h_{R},h_{Z},r_{s})$. Ignore potential 14.
# For each potential model, the MCMC chains have the following values :
# c,vo/220,dist/22.,pmo_parallel,pmo_perp, ln(sigv) and lnlike

# %%
def determine_nburn(filename='../pal5_mcmc/mwpot14-fitsigma-0.dat',
                    threshold=0.1,skip=50,
                    return_nsamples=False):
    """Function to detemrine an appropriate nburn for a given chain"""
    # Load the data
    data= numpy.loadtxt(filename,comments='#',delimiter=',')
    lndata= numpy.reshape(data[:,-1],(len(data[:,5])//nwalkers,nwalkers))
    # Perform a running diff wrt skip less
    diff= (lndata-numpy.roll(lndata,skip,axis=0))
    diff[:skip]= -100. # Make sure it's not within the first hundred
    maxln= numpy.nanmax(lndata)
    try:
        indx= (numpy.fabs(numpy.median(diff,axis=1)) < threshold)\
                       *((maxln-numpy.nanmax(lndata,axis=1)) < 1.25)
        if maxln > -22.5:
            indx*= numpy.std(lndata,axis=1) < 3.
        if return_nsamples:
            return len(data)-numpy.arange(len(lndata))[indx][0]*nwalkers
        else:
            return numpy.arange(len(lndata))[indx][0]*nwalkers
    except IndexError:
        if return_nsamples: return 100.
        else: return numpy.prod(lndata.shape)-100


nwalkers= 12

#from each MCMC chain file, pick nsamples
nsamples= 1


pot_ind=np.arange(0,32,1)
pot_ind=np.delete(pot_ind,14)

t_age= np.linspace(0.,5.,1001)/bovy_conversion.time_in_Gyr(vo,ro)

peri_all=[]

import csv
csvdens= open('pot_params.dat','w')
denswriter= csv.writer(csvdens,delimiter=',')

for pindx in pot_ind:
    
    print (pindx)
    # Load this potential
    fn= '../GMC/pal5_mcmc/mwpot14-fitsigma-%i.dat' % pindx
    with open(fn,'rb') as savefile:
        line1= savefile.readline()
    potparams= [float(s) for s in (line1.split(':'.encode())[1].split(','.encode()))]
    #all_potparams[ii]= potparams
    
    denswriter.writerow(potparams)

    tnburn= determine_nburn(fn)
    tdata= numpy.loadtxt(fn,comments='#',delimiter=',')
    tdata= tdata[tnburn::]
    
    print (min(tdata[:,3]),max(tdata[:,3]))
    
    rand_indx=random.sample(range(len(tdata)),nsamples)
    
    peri=[]
    c=1
    
      
    for jj in rand_indx:
            
        tvo= tdata[jj][1]*_REFV0
        pot= MWPotential2014Likelihood.setup_potential(potparams,tdata[jj][0],False,False,
                                                       pal5_util_MWfit._REFR0,tvo)

        # Now compute the stream model for this setup
        dist= tdata[jj][2]*22.
        pmra= -2.296+tdata[jj][3]+tdata[jj][4]
        pmdecpar= 2.257/2.296
        pmdecperp= -2.296/2.257
        pmdec= -2.257+tdata[jj][3]*pmdecpar+tdata[jj][4]*pmdecperp
        vlos= -58.7
        sigv= 0.4*numpy.exp(tdata[jj][5])
        
        
        prog= Orbit([229.018,-0.124,dist,pmra,pmdec,vlos],
                    radec=True,ro=ro,vo=tvo,
                    solarmotion=[-11.1,24.,7.25]).flip()
        
        prog.integrate(t_age,pot)
        peri.append(prog.rperi())
        
    peri_all.append(peri)
    
    
csvdens.flush()
csvdens.close()

# %%
#plot histogram of pericenter

plt.figure(figsize=(10,15))

for ii in range(31):
    plt.subplot(8,4,ii+1)
    plt.hist(peri_all[ii],bins='scott')
    plt.xlabel(r'$r_{peri}$ (kpc)')
    
plt.tight_layout()
plt.show()

# %%
#pal5_mcmc_selected_chains_pot{}.dat files were generated on the cluster, they contain 2000 samples 
#from each mcmc chain file

#peri  pmpar c/a  vc 229.018,-0.124,dist,pmra,pmdec,vlos

pot_ind=np.arange(0,32,1)
pot_ind=np.delete(pot_ind,14)

peri_all=[]
pmpar=[]
pot_indx=[]


for jj in range(31):
    dat=numpy.genfromtxt('../GMC/pal5_mcmc/pal5_mcmc_selected_chains_pot{}.dat'.format(pot_ind[jj]),delimiter=',',usecols=(0,1))
    peri_all.append(dat[:,0])
    pmpar.append(dat[:,1])
    pot_indx.append(pot_ind[jj])

# %%
#determine min and max pericenter, apply pmpar~ -0.4 selection and compare the pericenter distribution
peri_flat_list = [item for sublist in peri_all for item in sublist]

print (len(peri_flat_list))

pmpar_flat_list = [item for sublist in pmpar for item in sublist]

print (len(pmpar_flat_list))

peri_pmpar_select=[]

for ii in range(len(pmpar_flat_list)):
    if -0.42 < pmpar_flat_list[ii] < -0.38 :
        peri_pmpar_select.append(peri_flat_list[ii])
        
print (len(peri_pmpar_select))

print (min(peri_flat_list),max(peri_flat_list))

# %%
plt.figure(figsize=(10,10))
plt.hist(peri_flat_list,bins='scott',density=True)
plt.hist(peri_pmpar_select,bins='scott',histtype='step',color='red',density=True)
plt.xlim(4.,8.5)
plt.xlabel(r'$r_{perp}$ (kpc)')
#plt.savefig('pal5_mcmc_chains.pdf')
plt.show()

# %%
#setup a grid of pericenters between min and max and select the corresponding Pal5 orbit and potential

peri_min=4.68
peri_max=8.01

peri_grid=np.linspace(peri_min,peri_max,5)

print (peri_grid)

peri_bin_edge=[]

fo=open('rperi_grid_select.dat','w')
fowriter= csv.writer(fo,delimiter=',')

#define fine bin width to collect a sample of points
for ii in range(len(peri_grid)):
    peri_bin_lo=peri_grid[ii]-0.1
    peri_bin_hi=peri_grid[ii]+0.1
    peri_ind=[]
    
    while len(peri_ind) == 0 :
        
    
        pot_indx=np.random.choice(pot_ind,size=1)[0]
        print ('pot_indx =%i'%pot_indx)

        dat=numpy.genfromtxt('../GMC/pal5_mcmc/pal5_mcmc_selected_chains_pot{}.dat'.format(pot_indx),delimiter=',')
        peri=dat[:,0]
        flat_c=dat[:,2]
        vc=dat[:,3]
        sigv=dat[:,4]
        orbits=dat[:,(5,6,7,8,9,10)]

        for jj in range(len(peri)):
            if peri_bin_lo <= peri[jj] <= peri_bin_hi :
                peri_ind.append(jj)
                
        print (len(peri_ind))
    
            
    orb_ind=np.random.choice(peri_ind,size=1)[0]
    
    out=[pot_indx,peri[orb_ind],flat_c[orb_ind],vc[orb_ind],sigv[orb_ind]]
    out.extend(list(orbits[orb_ind]))
    
    fowriter.writerow(out)
    
fo.flush()
fo.close()

# %%
import GMC_util
import pal5_util

#sdf= pal5_util.setup_pal5model()
sdf0=GMC_util.make_nondefault_pal5stream(0)
sdf1=GMC_util.make_nondefault_pal5stream(1)
sdf2=GMC_util.make_nondefault_pal5stream(2)
sdf3=GMC_util.make_nondefault_pal5stream(3)
sdf4=GMC_util.make_nondefault_pal5stream(4)
# Out:
# 4.68
# galpyWarning: WARNING: Rnorm keyword input to streamdf is deprecated in favor of the standard ro keyword
# galpyWarning: WARNING: Vnorm keyword input to streamdf is deprecated in favor of the standard vo keyword
# galpyWarning: In versions >1.3, the output unit of streamdf.misalignment has been changed to radian (from degree before)
# 5.52
# 6.4
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:239: RuntimeWarning: invalid value encountered in sqrt
#   Jr= self.amp/nu.sqrt(-2.*E)\
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:242: RuntimeWarning: invalid value encountered in power
#   Omegar= (-2.*E)**1.5/self.amp
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:260: RuntimeWarning: invalid value encountered in arccos
#   eta= nu.arccos(coseta)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:266: RuntimeWarning: invalid value encountered in sqrt
#   tan11= nu.arctan(nu.sqrt((1.+e)/(1.-e))*nu.tan(0.5*eta))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:267: RuntimeWarning: invalid value encountered in sqrt
#   tan12= nu.arctan(nu.sqrt((1.+e+2.*self.b/c)/(1.-e+2.*self.b/c))*nu.tan(0.5*eta))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:269: RuntimeWarning: invalid value encountered in less
#   tan11[tan11 < 0.]+= nu.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:270: RuntimeWarning: invalid value encountered in less
#   tan12[tan12 < 0.]+= nu.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochroneApprox.py:763: RuntimeWarning: invalid value encountered in less
#   w= diff < -6.
#
# /home/nil/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: Invalid value encountered in median for 1 results
#   r = func(a, **kwargs)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py:2010: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/df_src/streamdf.py:3137: RuntimeWarning: invalid value encountered in greater
#   diffAngles[(diffAngles > numpy.pi)]= diffAngles[(diffAngles > numpy.pi)]-2.*numpy.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/df_src/streamdf.py:3138: RuntimeWarning: invalid value encountered in less
#   diffAngles[(diffAngles < -numpy.pi)]= diffAngles[(diffAngles < -numpy.pi)]+2.*numpy.pi
#
# galpyWarning: Full radial angle range not covered for at least one object; actions are likely not reliable
# /home/nil/anaconda3/lib/python3.6/site-packages/numpy/lib/scimath.py:120: RuntimeWarning: invalid value encountered in less
#   if any(isreal(x) & (x < 0)):
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_coords.py:1011: RuntimeWarning: invalid value encountered in less
#   if isinstance(phi,nu.ndarray): phi[phi<0.]+= 2.*nu.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_coords.py:569: RuntimeWarning: invalid value encountered in less
#   l[cosl < 0.]= nu.pi-l[cosl < 0.]
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_coords.py:570: RuntimeWarning: invalid value encountered in greater_equal
#   l[(cosl >= 0.)*(sinl < 0.)]+= 2.*nu.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_coords.py:570: RuntimeWarning: invalid value encountered in less
#   l[(cosl >= 0.)*(sinl < 0.)]+= 2.*nu.pi
#
# using estimateBIsochrone
# b=0.642869
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/orbit_src/FullOrbit.py:616: RuntimeWarning: invalid value encountered in arccos
#   phi= nu.arccos(tmp_out[:,0]/R)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:245: RuntimeWarning: invalid value encountered in less
#   indx= Lz < 0.
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:256: RuntimeWarning: invalid value encountered in greater
#   pindx= (coseta > 1.)*(coseta < (1.+10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:256: RuntimeWarning: invalid value encountered in less
#   pindx= (coseta > 1.)*(coseta < (1.+10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:258: RuntimeWarning: invalid value encountered in less
#   pindx= (coseta < -1.)*(coseta > (-1.-10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:258: RuntimeWarning: invalid value encountered in greater
#   pindx= (coseta < -1.)*(coseta > (-1.-10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:263: RuntimeWarning: invalid value encountered in less
#   vrindx= (vR*sintheta+vz*costheta) < 0.
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:268: RuntimeWarning: invalid value encountered in greater
#   vzindx= (-vz*sintheta+vR*costheta) > 0.
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:271: RuntimeWarning: invalid value encountered in greater
#   pindx= (Lz/L > 1.)*(Lz/L < (1.+10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:271: RuntimeWarning: invalid value encountered in less
#   pindx= (Lz/L > 1.)*(Lz/L < (1.+10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:273: RuntimeWarning: invalid value encountered in less
#   pindx= (Lz/L < -1.)*(Lz/L > (-1.-10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:273: RuntimeWarning: invalid value encountered in greater
#   pindx= (Lz/L < -1.)*(Lz/L > (-1.-10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:275: RuntimeWarning: invalid value encountered in arccos
#   i= nu.arccos(Lz/L)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:277: RuntimeWarning: invalid value encountered in greater
#   pindx= (sinpsi > 1.)*(sinpsi < (1.+10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:277: RuntimeWarning: invalid value encountered in less
#   pindx= (sinpsi > 1.)*(sinpsi < (1.+10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:279: RuntimeWarning: invalid value encountered in less
#   pindx= (sinpsi < -1.)*(sinpsi > (-1.-10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:279: RuntimeWarning: invalid value encountered in greater
#   pindx= (sinpsi < -1.)*(sinpsi > (-1.-10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:281: RuntimeWarning: invalid value encountered in arcsin
#   psi= nu.arcsin(sinpsi)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:287: RuntimeWarning: invalid value encountered in greater
#   pindx= (sinu > 1.)*(sinu < (1.+10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:287: RuntimeWarning: invalid value encountered in less
#   pindx= (sinu > 1.)*(sinu < (1.+10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:289: RuntimeWarning: invalid value encountered in less
#   pindx= (sinu < -1.)*(sinu > (-1.-10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:289: RuntimeWarning: invalid value encountered in greater
#   pindx= (sinu < -1.)*(sinu > (-1.-10.**-7.))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:291: RuntimeWarning: invalid value encountered in arcsin
#   u= nu.arcsin(sinu)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# /mnt/d/Dropbox/streamgap-pepper/Baryonic_effects_on_Pal5/GMC_util.py in make_nondefault_pal5stream(chain_ind, leading, timpact, b, hernquist, td, length_factor, **kwargs)
#      67         try :
# ---> 68             sdf= pal5_util.setup_pal5model_MWfit(timpact=timpact,pot=pot,orb=orb,hernquist=hernquist,leading=leading,age=td,sigv=sigv)
#      69
#
# /mnt/d/Dropbox/streamgap-pepper/Baryonic_effects_on_Pal5/pal5_util.py in setup_pal5model_MWfit(leading, pot, orb, timpact, b, hernquist, age, sigv, singleImpact, length_factor, **kwargs)
#      92                       vsun=[-11.1,V0+24.,7.25],
# ---> 93                       custom_transform=_TPAL5)
#      94     elif singleImpact:
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/df_src/streamdf.py in __init__(self, sigv, progenitor, pot, aA, useTM, tdisrupt, sigMeanOffset, leading, sigangle, deltaAngleTrack, nTrackChunks, nTrackIterations, progIsTrack, ro, vo, Vnorm, Rnorm, R0, Zsun, vsun, multi, interpTrack, useInterp, nosetup, nospreadsetup, approxConstTrackFreq, useTMHessian, custom_transform)
#     212             self.calc_stream_lb()
# --> 213             if not nospreadsetup: self._determine_stream_spread()
#     214         return None
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/df_src/streamdf.py in _determine_stream_spread(self, simple)
#    1207             #Eigen decomposition for interpolation
# -> 1208             teig= numpy.linalg.eig(allErrCovsXY[ii])
#    1209             #Sort them to match them up later
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in eig(a)
#    1249     _assertNdSquareness(a)
# -> 1250     _assertFinite(a)
#    1251     t, result_t = _commonType(a)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in _assertFinite(*arrays)
#     219         if not (isfinite(a).all()):
# --> 220             raise LinAlgError("Array must not contain infs or NaNs")
#     221
#
# LinAlgError: Array must not contain infs or NaNs
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-d23babae1320> in <module>()
#       5 sdf0=GMC_util.make_nondefault_pal5stream(0)
#       6 sdf1=GMC_util.make_nondefault_pal5stream(1)
# ----> 7 sdf2=GMC_util.make_nondefault_pal5stream(2)
#       8 sdf3=GMC_util.make_nondefault_pal5stream(3)
#       9 sdf4=GMC_util.make_nondefault_pal5stream(4)
#
# /mnt/d/Dropbox/streamgap-pepper/Baryonic_effects_on_Pal5/GMC_util.py in make_nondefault_pal5stream(chain_ind, leading, timpact, b, hernquist, td, length_factor, **kwargs)
#      84             print ("b=%f"%isob)
#      85
# ---> 86             sdf=pal5_util.setup_pal5model_MWfit(leading=leading,pot=pot,orb=orb,timpact=timpact,b=isob,hernquist=hernquist,age=td,sigv=sigv)
#      87
#      88         return sdf
#
# /mnt/d/Dropbox/streamgap-pepper/Baryonic_effects_on_Pal5/pal5_util.py in setup_pal5model_MWfit(leading, pot, orb, timpact, b, hernquist, age, sigv, singleImpact, length_factor, **kwargs)
#      91                       Rnorm=R0,Vnorm=V0,R0=R0,
#      92                       vsun=[-11.1,V0+24.,7.25],
# ---> 93                       custom_transform=_TPAL5)
#      94     elif singleImpact:
#      95         sdf= streamgapdf(sigv/V0,progenitor=obs,
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/df_src/streamdf.py in __init__(self, sigv, progenitor, pot, aA, useTM, tdisrupt, sigMeanOffset, leading, sigangle, deltaAngleTrack, nTrackChunks, nTrackIterations, progIsTrack, ro, vo, Vnorm, Rnorm, R0, Zsun, vsun, multi, interpTrack, useInterp, nosetup, nospreadsetup, approxConstTrackFreq, useTMHessian, custom_transform)
#     205         if not nosetup:
#     206             self._determine_nTrackIterations(nTrackIterations)
# --> 207             self._determine_stream_track(nTrackChunks)
#     208             self._useInterp= useInterp
#     209             if interpTrack or self._useInterp:
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/df_src/streamdf.py in _determine_stream_track(self, nTrackChunks)
#    1022                                                              self._dsigomeanProgDirection,
#    1023                                                              lambda x:self.meanOmega(x,use_physical=False),
# -> 1024                                                              thetasTrack[ii])
#    1025                     allAcfsTrack[ii,:]= multiOut[0]
#    1026                     alljacsTrack[ii,:,:]= multiOut[1]
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/df_src/streamdf.py in _determine_stream_track_single(aA, progenitorTrack, trackt, progenitor_angle, sigMeanSign, dsigomeanProgDirection, meanOmega, thetasTrack)
#    3109     detdOdJ= numpy.empty(6)
#    3110     #Calculate
# -> 3111     tacfs= aA.actionsFreqsAngles(progenitorTrack(trackt))
#    3112     allAcfsTrack[0]= tacfs[0][0]
#    3113     allAcfsTrack[1]= tacfs[1][0]
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_conversion.py in wrapper(*args, **kwargs)
#     788     def wrapper(*args,**kwargs):
#     789         if len(args) < 3: # orbit input
# --> 790             return method(*args,**kwargs)
#     791         ro= kwargs.get('ro',None)
#     792         if ro is None and hasattr(args[0],'_ro'):
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_conversion.py in wrapped(*args, **kwargs)
#     778                 return newOut
#     779             else:
# --> 780                 return method(*args,**kwargs)
#     781         return wrapped
#     782     return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngle.py in actionsFreqsAngles(self, *args, **kwargs)
#     328         """
#     329         try:
# --> 330             return self._actionsFreqsAngles(*args,**kwargs)
#     331         except AttributeError: #pragma: no cover
#     332             raise NotImplementedError("'actionsFreqsAngles' method not implemented for this actionAngle module")
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochroneApprox.py in _actionsFreqsAngles(self, *args, **kwargs)
#     236                 and not 'ts' in kwargs:
#     237             kwargs['ts']= args[0][0]._orb.t
# --> 238         R,vR,vT,z,vz,phi= self._parse_args(True,_firstFlip,*args)
#     239         if 'ts' in kwargs and not kwargs['ts'] is None:
#     240             ts= kwargs['ts']
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochroneApprox.py in _parse_args(self, freqsAngles, _firstFlip, *args)
#     617                 [o.integrate(self._tsJ,pot=self._pot,
#     618                              method=self._integrate_method,
# --> 619                              dt=self._integrate_dt) for o in os]
#     620                 if _firstFlip:
#     621                     for o in os:
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochroneApprox.py in <listcomp>(.0)
#     617                 [o.integrate(self._tsJ,pot=self._pot,
#     618                              method=self._integrate_method,
# --> 619                              dt=self._integrate_dt) for o in os]
#     620                 if _firstFlip:
#     621                     for o in os:
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/orbit_src/Orbit.py in integrate(self, t, pot, method, dt)
#     496         if not _check_integrate_dt(t,dt):
#     497             raise ValueError('dt input (integrator stepsize) for Orbit.integrate must be an integer divisor of the output stepsize')
# --> 498         self._orb.integrate(t,pot,method=method,dt=dt)
#     499
#     500     def integrate_dxdv(self,dxdv,t,pot,method='dopr54_c',
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/orbit_src/FullOrbit.py in integrate(self, t, pot, method, dt)
#      91         self.t= nu.array(t)
#      92         self._pot= pot
# ---> 93         self.orbit= _integrateFullOrbit(self.vxvv,pot,t,method,dt)
#      94
#      95     @physical_conversion('energy')
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/orbit_src/FullOrbit.py in _integrateFullOrbit(vxvv, pot, t, method, dt)
#     611         #integrate
#     612         tmp_out, msg= integrateFullOrbit_c(pot,this_vxvv,
# --> 613                                            t,method,dt=dt)
#     614         #go back to the cylindrical frame
#     615         R= nu.sqrt(tmp_out[:,0]**2.+tmp_out[:,1]**2.)
#
# ~/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/orbit_src/integrateFullOrbit.py in integrateFullOrbit_c(pot, yo, t, int_method, rtol, atol, dt)
#     330
#     331     if int(err.value) == -10: #pragma: no cover
# --> 332         raise KeyboardInterrupt("Orbit integration interrupted by CTRL-C (SIGINT)")
#     333
#     334     #Reset input arrays
#
# KeyboardInterrupt: Orbit integration interrupted by CTRL-C (SIGINT)

# %%
orb,pot,sigv=GMC_util.set_prog_potential(2)

print (orb,pot,sigv)
# Out:
# 6.4
# [229.018, -0.124, 23.09762906, -2.44048274, -2.4786990775270126, -58.7] [<galpy.potential_src.PowerSphericalPotentialwCutoff.PowerSphericalPotentialwCutoff object at 0x7f8a6c24e8d0>, <galpy.potential_src.MiyamotoNagaiPotential.MiyamotoNagaiPotential object at 0x7f8a6c24ecf8>, <galpy.potential_src.TwoPowerTriaxialPotential.TriaxialNFWPotential object at 0x7f8a6c24efd0>] 0.22348778674136083

# %%
from galpy.orbit import Orbit
prog=Orbit(orb,radec=True,ro=ro,vo=vo,solarmotion=[-11.1,24.,7.25])

sdf=pal5_util_MWfit.setup_sdf(pot,prog,sigv,td=5.,ro=ro,vo=vo,nTrackChunks=11,isob=0.8,
              trailing_only=True,verbose=True,useTM=False)
# Out:
# 0.722558 0.8
# galpyWarning: In versions >1.3, the output unit of streamdf.misalignment has been changed to radian (from degree before)
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:239: RuntimeWarning: invalid value encountered in sqrt
#   Jr= self.amp/nu.sqrt(-2.*E)\
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:242: RuntimeWarning: invalid value encountered in power
#   Omegar= (-2.*E)**1.5/self.amp
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:260: RuntimeWarning: invalid value encountered in arccos
#   eta= nu.arccos(coseta)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:266: RuntimeWarning: invalid value encountered in sqrt
#   tan11= nu.arctan(nu.sqrt((1.+e)/(1.-e))*nu.tan(0.5*eta))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:267: RuntimeWarning: invalid value encountered in sqrt
#   tan12= nu.arctan(nu.sqrt((1.+e+2.*self.b/c)/(1.-e+2.*self.b/c))*nu.tan(0.5*eta))
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:269: RuntimeWarning: invalid value encountered in less
#   tan11[tan11 < 0.]+= nu.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochrone.py:270: RuntimeWarning: invalid value encountered in less
#   tan12[tan12 < 0.]+= nu.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/actionAngle_src/actionAngleIsochroneApprox.py:763: RuntimeWarning: invalid value encountered in less
#   w= diff < -6.
#
# /home/nil/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3250: RuntimeWarning: Invalid value encountered in median for 1 results
#   r = func(a, **kwargs)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py:2010: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/df_src/streamdf.py:3137: RuntimeWarning: invalid value encountered in greater
#   diffAngles[(diffAngles > numpy.pi)]= diffAngles[(diffAngles > numpy.pi)]-2.*numpy.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/df_src/streamdf.py:3138: RuntimeWarning: invalid value encountered in less
#   diffAngles[(diffAngles < -numpy.pi)]= diffAngles[(diffAngles < -numpy.pi)]+2.*numpy.pi
#
# galpyWarning: Full radial angle range not covered for at least one object; actions are likely not reliable
# /home/nil/anaconda3/lib/python3.6/site-packages/numpy/lib/scimath.py:120: RuntimeWarning: invalid value encountered in less
#   if any(isreal(x) & (x < 0)):
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_coords.py:1011: RuntimeWarning: invalid value encountered in less
#   if isinstance(phi,nu.ndarray): phi[phi<0.]+= 2.*nu.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_coords.py:569: RuntimeWarning: invalid value encountered in less
#   l[cosl < 0.]= nu.pi-l[cosl < 0.]
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_coords.py:570: RuntimeWarning: invalid value encountered in greater_equal
#   l[(cosl >= 0.)*(sinl < 0.)]+= 2.*nu.pi
#
# /home/nil/anaconda3/lib/python3.6/site-packages/galpy-1.4.dev0-py3.6-linux-x86_64.egg/galpy/util/bovy_coords.py:570: RuntimeWarning: invalid value encountered in less
#   l[(cosl >= 0.)*(sinl < 0.)]+= 2.*nu.pi

# %%
sdf.plotTrack(xrange=[-1.4,-0.4],yrange=[-0.5,2.2],label='Fid')
sdf0.plotTrack(overplot=True,c='k',label='4.68 kpc')
sdf1.plotTrack(overplot=True,label='5.52 kpc')
sdf2.plotTrack(overplot=True,label='6.4 kpc')
sdf3.plotTrack(overplot=True,label='7.19 kpc')
sdf4.plotTrack(overplot=True,label='7.92 kpc')
plt.legend(loc='lower left')
plt.savefig('track.pdf')

# %%
sdf.plotTrack(d1='x',d2='y',xrange=[-1.5,-0.2],yrange=[0.,1.4],label='Fid')
sdf0.plotTrack(overplot=True,c='k',d1='x',d2='y',label='4.68 kpc')
sdf1.plotTrack(overplot=True,d1='x',d2='y',label='5.52 kpc')
sdf2.plotTrack(overplot=True,d1='x',d2='y',label='6.4 kpc')
sdf3.plotTrack(overplot=True,d1='x',d2='y',label='7.19 kpc')
sdf4.plotTrack(overplot=True,d1='x',d2='y',label='7.92 kpc')
plt.legend(loc='lower right')
plt.savefig('track_xy.pdf')
